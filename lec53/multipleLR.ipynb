# %%
import numpy as np
import pandas as pd
import os

from sklearn.datasets import make_regression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# multiple linear regression is same as linear regression just iput columns are more than 1

x,y = make_regression(n_samples=100 , n_features=2, n_informative=2, n_targets=1, noise=50)

df = pd.DataFrame({'feature1':x[:, 0], 'feature2':x[:, 1] , 'target':y })
df.shape
# Out:
# (100, 3)

# %%
import plotly.express as px
import plotly.graph_objects as go
fig = px.scatter_3d(df, x='feature1', y= 'feature2', z='target')
fig.show()

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2, random_state=3)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)
y_pred
# Out:
# array([  53.64705699,   42.48105645,  -12.53711473,  -82.24781775,
#         -79.38517043,   30.04020253,  109.97969949,  -52.09721535,
#         -31.66009182,   25.9991024 ,   40.60299909,    4.44291846,
#         119.12258237, -124.3899108 ,  -40.97151612,  -41.96687141,
#          56.19384396,   -8.91469597,  -11.08096039,   30.45691457])

# %%
print("MAE", mean_absolute_error(y_test, y_pred))
print("MSE", mean_squared_error(y_test, y_pred))
print("R2", r2_score(y_test, y_pred))
# Out:
# MAE 33.52950295229246
# MSE 1751.4175147732021
# R2 0.767389565442767

# %%
lr.coef_
# Out:
# array([49.7210452 , 21.03489023])

# %%
lr.intercept_
# Out:
# 2.1187844275387504
